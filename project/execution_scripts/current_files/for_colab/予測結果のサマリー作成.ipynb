# %% [markdown]
# #モジュールのインポート

# %%
# パスを通す
import os
from pathlib import Path
import sys
PROJECT_FOLDER = '/content/drive/MyDrive/enrich_me'
ORIGINAL_MODULES = PROJECT_FOLDER + '/modules'
FILE_MODULES = PROJECT_FOLDER + '/source_codes/current_files'
THIRDPARTY_MODULES = '/content/drive/MyDrive/python/Lib/site-packages'
for module_folder in [ORIGINAL_MODULES, FILE_MODULES, THIRDPARTY_MODULES]:
    if module_folder not in sys.path:
        sys.path.append(module_folder)

# %%
sys.path
# Out:
# ['/content',
#  '/env/python',
#  '/usr/lib/python310.zip',
#  '/usr/lib/python3.10',
#  '/usr/lib/python3.10/lib-dynload',
#  '',
#  '/usr/local/lib/python3.10/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.10/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '/content/drive/MyDrive/enrich_me/modules',
#  '/content/drive/MyDrive/enrich_me/source_codes/current_files',
#  '/content/drive/MyDrive/python/Lib/site-packages']

# %%
# モジュールのインポート
import paths
from datetime import datetime
from summarize_ls_model import summarize_ls_model
from IPython.display import HTML

# %% [markdown]
# #パラメータ設定

# %%
#ストラテジーの名前
strategy1_name = '48Sectors'
strategy2_name = '48Sectors_relearn'
#ベンチマークの採否
apply_benchmark = True
#モデルのデータセットのパス
model1_path = f'{paths.ML_DATASETS_FOLDER}/New48sectors.pkl.gz'
model2_path = f'{paths.ML_DATASETS_FOLDER}/New48sectors_relearn240601.pkl.gz'
#テストの開始日と終了日
start_date = datetime(2022,1,1)
end_date = datetime(2024,3,31)

# %% [markdown]
# #実行

# %%
html_strategy1_vs_strategy2, html_strategy1_vs_benchmark = \
    summarize_ls_model(strategy1_name, strategy2_name, apply_benchmark,
                       model1_path, model2_path,
                       start_date, end_date)
# Out:
#                       Target      Pred  Target_Rank  Pred_Rank
# Date       Sector
# 2022-01-04 ITインフラ  -0.001031  0.000630         10.0       47.0
#            ドラッグストア  0.005724  0.000450         27.0       46.0
#            ビジネス     0.009708  0.000831         38.0       48.0
# 2022-01-05 自動車      0.013101  0.000781         43.0       47.0
#            重工業      0.016360  0.000626         47.0       46.0
# ...                      ...       ...          ...        ...
# 2024-03-28 ビジネス    -0.006943  0.000774         26.0       46.0
#            医薬品卸    -0.013177  0.000852         12.0       48.0
# 2024-03-29 医薬品卸     0.010332  0.000212         34.0       46.0
#            重工業      0.033496  0.000647         48.0       47.0
#            非鉄金属     0.016851  0.001091         45.0       48.0
#
# [1644 rows x 4 columns]
# 48Sectorsの読み込みが完了しました。
# 全期間
# 母集団の推定（99.7%）
# 平均リターン: 0.1345% (worst: 0.0675%, best: 0.2014%)
# 標準偏差: 0.005255 (worst:0.005768, best:0.004819)
# ...

# %% [markdown]
# #出力

# %%
display(HTML(html_strategy1_vs_strategy2))
# Out:
# <!-- generated by QuantStats for Python -->
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#     <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
#     <title>Tearsheet (generated by QuantStats)</title>
#     <meta name="robots" content="noindex, nofollow">
#     <link rel="shortcut icon" href="https://qtpylib.io/favicon.ico" type="image/x-icon">
#     <style>
# ...

# %%
if html_strategy1_vs_benchmark is not None:
    display(HTML(html_strategy1_vs_benchmark))
# Out:
# <!-- generated by QuantStats for Python -->
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#     <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
#     <title>Tearsheet (generated by QuantStats)</title>
#     <meta name="robots" content="noindex, nofollow">
#     <link rel="shortcut icon" href="https://qtpylib.io/favicon.ico" type="image/x-icon">
#     <style>
# ...
