# %% [markdown]
# #モジュールのインポート等

# %%
#パスを通す
import os
from pathlib import Path
import sys
if os.name == 'nt':
    PROJECT_FOLDER = str(Path(os.path.abspath(" ")).parents[2])
else:
    PROJECT_FOLDER = '/content/drive/MyDrive/enrich_me'
ORIGINAL_MODULES = PROJECT_FOLDER + '/modules'
THIRDPARTY_MODULES = PROJECT_FOLDER + '/.venv/Lib/site-packages'
sys.path.append(ORIGINAL_MODULES)
sys.path.append(THIRDPARTY_MODULES)

#モジュールのインポート
from TradeHistoryAnalyzer import TradeHistoryAnalyzer
from datetime import datetime

# %% [markdown]
# #実行

# %%
tha = TradeHistoryAnalyzer(start_date=datetime(2023, 3, 1), end_date=datetime.today())
tha.display_result()
# Out:
#                 取得価格  利益（税引前）   利率（税引前）  利益（税引後）   利率（税引後）
# 日付
# 2023-07-24  13434250    -1378 -0.000103    -1378 -0.000103
# 2023-07-25  12665870    20540  0.001622    16648  0.001314
# 2023-07-26  14733400    74850  0.005080    59644  0.004048
# 2023-07-27  14125650   105330  0.007457    83932  0.005942
# 2023-07-28  15906970    -5470 -0.000344    -4359 -0.000274
# 2023-07-31  16345120   -50860 -0.003112   -40527 -0.002479
# 2023-08-02  16021290     8570  0.000535     6829  0.000426
# 2023-08-03  15926800   175660  0.011029   139974  0.008789
# 2023-08-04  16445000    26080  0.001586    20782  0.001264
# 2023-08-07  16684280   119720  0.007176    95399  0.005718
# 2023-08-08  16676590    19680  0.001180    15682  0.000940
# 2023-08-09  16813740   -32400 -0.001927   -25818 -0.001536
# 2023-08-10  16515400  -180400 -0.010923  -143752 -0.008704
# 2023-08-14  16275210    21850  0.001343    17412  0.001070
# 2023-08-15  16483010   -59070 -0.003584   -47070 -0.002856
# ...
